# %% [markdown]
# #**Let's start**#

# %% [markdown]
# 1.*Know your Data*

# %% [markdown]
# Import library:

# %%
import os
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# *Load the Dataset...*

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\Hotel Bookings.csv")

# %% [markdown]
# *Datasets first look*

# %%
data.head()     #here head will print the first five row of the dataset.
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()    #here tail will print the last five columns of the dataset.
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# *Count the Rows and Columns:*

# %%
data.shape     #here shape will print the no.of rows and columns.
# Out:
# (119390, 32)

# %%
print("the no.of Rows are:",data.shape[0])     #here we will print the no.of rows sepretly. 
print("the no.of columns are:",data.shape[1])    #here we will print the no.of columns sepretly.
# Out:
# the no.of Rows are: 119390
# the no.of columns are: 32

# %% [markdown]
# *Dataset Information*

# %%
data.info()    #here we print info.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# *Dataset Columns Name*

# %%
data.columns    #here we will print the all columns name.
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# *Dataset Duplicate Value*

# %%
dup=data.duplicated()     #here we will print the duplicated value of the dataset.
dup
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %%
print("the total no.of duplicates are:",dup.sum())         #here we will print the sum or number of duplicated value of the given dataset.
# Out:
# the total no.of duplicates are: 31994

# %% [markdown]
# *Missing Value or Null Value*

# %%
null=data.isnull()     #here we will print the null value.
null
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
null.sum().sort_values()  #here we will count the null value in each columns.
# Out:
# hotel                                  0
# total_of_special_requests              0
# required_car_parking_spaces            0
# adr                                    0
# customer_type                          0
# days_in_waiting_list                   0
# deposit_type                           0
# booking_changes                        0
# assigned_room_type                     0
# reserved_room_type                     0
# previous_bookings_not_canceled         0
# previous_cancellations                 0
# is_repeated_guest                      0
# reservation_status                     0
# distribution_channel                   0
# reservation_status_date                0
# meal                                   0
# babies                                 0
# adults                                 0
# stays_in_week_nights                   0
# stays_in_weekend_nights                0
# arrival_date_day_of_month              0
# market_segment                         0
# ...

# %%
null.sum().sum()     #here we will print the sum of all the null value columns wise.
# Out:
# 129425

# %% [markdown]
# *Replacing the null or missing value*

# %% [markdown]
# * here we find the missing value in this columns:children,country,agent,company

# %%
data["children"].fillna(data.children.mean(),inplace=True)    #Here we replace the null value with mean value.
data["children"]=data["children"].astype(int)             #here we convert the chindren column into int type.

# %%
data["country"].fillna(0 ,inplace= True)         # Here we replace the missing value with 
data["country"].astype(int)     # here we convert the country column into int type.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 data["country"].fillna(0 ,inplace= True)         # Here we replace the missing value with
# ----> 2 data["country"].astype(int)     # here we convert the country column into int type.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...
